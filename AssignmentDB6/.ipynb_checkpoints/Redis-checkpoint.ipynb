# %%
! pip install redis
# Out:
# Requirement already satisfied: redis in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (4.3.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis) (4.0.2)
# Requirement already satisfied: packaging>=20.4 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis) (21.0)
# Requirement already satisfied: deprecated>=1.2.3 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.3->redis) (1.12.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.4->redis) (3.0.4)

# %%
! pip install redis_dict
# Out:
# Requirement already satisfied: redis_dict in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (1.6.0)
# Requirement already satisfied: future in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis_dict) (0.18.2)
# Requirement already satisfied: redis in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis_dict) (4.3.1)
# Requirement already satisfied: packaging>=20.4 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis->redis_dict) (21.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis->redis_dict) (4.0.2)
# Requirement already satisfied: deprecated>=1.2.3 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from redis->redis_dict) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.3->redis->redis_dict) (1.12.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.4->redis->redis_dict) (3.0.4)

# %%
# !pip install flask-bootstrap
# Out:
# Requirement already satisfied: flask-bootstrap in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (3.3.7.1)
# Requirement already satisfied: visitor in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from flask-bootstrap) (0.1.3)
# Requirement already satisfied: dominate in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from flask-bootstrap) (2.6.0)
# Requirement already satisfied: Flask>=0.8 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from flask-bootstrap) (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-bootstrap) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-bootstrap) (2.0.2)
# Requirement already satisfied: click>=5.1 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-bootstrap) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from Flask>=0.8->flask-bootstrap) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-bootstrap) (1.1.1)

# %%
# !pip install wtforms
# Out:
# Requirement already satisfied: wtforms in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (3.0.1)
# Requirement already satisfied: MarkupSafe in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (from wtforms) (1.1.1)

# %%
# !pip install json2html
# Out:
# Requirement already satisfied: json2html in /Users/jacobsimonsen/opt/anaconda3/lib/python3.9/site-packages (1.3.0)

# %%
import redis
import json
from json2html import *
import time

# %%
r = redis.Redis(db=1)

# %%
with open('url1.json') as json_file:
    data = json.load(json_file)
 
    # Print the type of data variable
    #print("Type:", type(data))
    
    #print("ITEMS: ", data.items())
      
    # Print the data of dictionary
    print("\nData:", data['data'][0]['ID IPEDS Occupation Parent'])
    print("\nData:", data['data'][0])
# Out:
# Data: Adminstrative
#
# Data: {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 51, 'Slug University': 'adler-university'}

# %%
#with open('url2.json') as json_file:
    #data = json.load(json_file)
 
    # Print the type of data variable
    #print("Type:", type(data))
    
    #print("ITEMS: ", data.items())
      
    # Print the data of dictionary
   # print("\nData:", data['data'][0]['ID Detailed Occupation'])
    # print("\nData:", data['data'][0])
# Out:
# Data: 111021
#
# Data: {'ID Detailed Occupation': '111021', 'Detailed Occupation': 'General & operations managers', 'ID Year': 2019, 'Year': '2019', 'Average Wage': 81531.30163756265, 'Average Wage Appx MOE': 1683.8922008483378, 'Slug Detailed Occupation': 'general-operations-managers'}

# %%
#print(type(data['data']))
for dic in data['data']:
    print(dic)
    print(data['data'].index(dic)+1)
    for key, val in dic.items():
        print(key, ":", val)
    print("-----------------------------------")
# Out:
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 51, 'Slug University': 'adler-university'}
# 1
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 05
# IPEDS Occupation : Management
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 51
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '06', 'IPEDS Occupation': 'Business and Financial Operations', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 14, 'Slug University': 'adler-university'}
# 2
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 06
# IPEDS Occupation : Business and Financial Operations
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 14
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '11', 'IPEDS Occupation': 'Sales and related', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 3
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 11
# IPEDS Occupation : Sales and related
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Healthcare', 'IPEDS Occupation Parent': 'Healthcare', 'ID IPEDS Occupation': '09', 'IPEDS Occupation': 'Healthcare Practioners and Technical', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 4
# ID IPEDS Occupation Parent : Healthcare
# IPEDS Occupation Parent : Healthcare
# ID IPEDS Occupation : 09
# IPEDS Occupation : Healthcare Practioners and Technical
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '13', 'IPEDS Occupation': 'Natural Resources, Construction, and Maintenance', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 5
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 13
# IPEDS Occupation : Natural Resources, Construction, and Maintenance
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '14', 'IPEDS Occupation': 'Production, Transportation, and Material Moving', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 6
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 14
# IPEDS Occupation : Production, Transportation, and Material Moving
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '03', 'IPEDS Occupation': 'Public service', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 7
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 03
# IPEDS Occupation : Public service
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '04', 'IPEDS Occupation': 'Librarians, Curators, Archivists, and Academic Affairs and Other Education Services', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 20, 'Slug University': 'adler-university'}
# 8
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 04
# IPEDS Occupation : Librarians, Curators, Archivists, and Academic Affairs and Other Education Services
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 20
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '08', 'IPEDS Occupation': 'Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 32, 'Slug University': 'adler-university'}
# 9
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 08
# IPEDS Occupation : Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 32
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '10', 'IPEDS Occupation': 'Service', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 3, 'Slug University': 'adler-university'}
# 10
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 10
# IPEDS Occupation : Service
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 3
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '12', 'IPEDS Occupation': 'Office and Administrative Support', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 10, 'Slug University': 'adler-university'}
# 11
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 12
# IPEDS Occupation : Office and Administrative Support
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 10
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '02', 'IPEDS Occupation': 'Research', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 12
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 02
# IPEDS Occupation : Research
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '07', 'IPEDS Occupation': 'Computer, Engineering, and Science', 'ID Year': 2020, 'Year': '2020', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 8, 'Slug University': 'adler-university'}
# 13
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 07
# IPEDS Occupation : Computer, Engineering, and Science
# ID Year : 2020
# Year : 2020
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 8
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 50, 'Slug University': 'adler-university'}
# 14
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 05
# IPEDS Occupation : Management
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 50
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '06', 'IPEDS Occupation': 'Business and Financial Operations', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 7, 'Slug University': 'adler-university'}
# 15
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 06
# IPEDS Occupation : Business and Financial Operations
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 7
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '11', 'IPEDS Occupation': 'Sales and related', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 16
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 11
# IPEDS Occupation : Sales and related
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Healthcare', 'IPEDS Occupation Parent': 'Healthcare', 'ID IPEDS Occupation': '09', 'IPEDS Occupation': 'Healthcare Practioners and Technical', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 17
# ID IPEDS Occupation Parent : Healthcare
# IPEDS Occupation Parent : Healthcare
# ID IPEDS Occupation : 09
# IPEDS Occupation : Healthcare Practioners and Technical
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '13', 'IPEDS Occupation': 'Natural Resources, Construction, and Maintenance', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 1, 'Slug University': 'adler-university'}
# 18
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 13
# IPEDS Occupation : Natural Resources, Construction, and Maintenance
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 1
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '14', 'IPEDS Occupation': 'Production, Transportation, and Material Moving', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 19
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 14
# IPEDS Occupation : Production, Transportation, and Material Moving
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '03', 'IPEDS Occupation': 'Public service', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 20
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 03
# IPEDS Occupation : Public service
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '04', 'IPEDS Occupation': 'Librarians, Curators, Archivists, and Academic Affairs and Other Education Services', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 21, 'Slug University': 'adler-university'}
# 21
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 04
# IPEDS Occupation : Librarians, Curators, Archivists, and Academic Affairs and Other Education Services
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 21
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '08', 'IPEDS Occupation': 'Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 32, 'Slug University': 'adler-university'}
# 22
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 08
# IPEDS Occupation : Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 32
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '10', 'IPEDS Occupation': 'Service', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 3, 'Slug University': 'adler-university'}
# 23
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 10
# IPEDS Occupation : Service
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 3
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '12', 'IPEDS Occupation': 'Office and Administrative Support', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 11, 'Slug University': 'adler-university'}
# 24
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 12
# IPEDS Occupation : Office and Administrative Support
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 11
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '02', 'IPEDS Occupation': 'Research', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 25
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 02
# IPEDS Occupation : Research
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '07', 'IPEDS Occupation': 'Computer, Engineering, and Science', 'ID Year': 2019, 'Year': '2019', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 7, 'Slug University': 'adler-university'}
# 26
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 07
# IPEDS Occupation : Computer, Engineering, and Science
# ID Year : 2019
# Year : 2019
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 7
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 45, 'Slug University': 'adler-university'}
# 27
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 05
# IPEDS Occupation : Management
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 45
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '06', 'IPEDS Occupation': 'Business and Financial Operations', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 8, 'Slug University': 'adler-university'}
# 28
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 06
# IPEDS Occupation : Business and Financial Operations
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 8
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '11', 'IPEDS Occupation': 'Sales and related', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 29
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 11
# IPEDS Occupation : Sales and related
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Healthcare', 'IPEDS Occupation Parent': 'Healthcare', 'ID IPEDS Occupation': '09', 'IPEDS Occupation': 'Healthcare Practioners and Technical', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 30
# ID IPEDS Occupation Parent : Healthcare
# IPEDS Occupation Parent : Healthcare
# ID IPEDS Occupation : 09
# IPEDS Occupation : Healthcare Practioners and Technical
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '13', 'IPEDS Occupation': 'Natural Resources, Construction, and Maintenance', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 1, 'Slug University': 'adler-university'}
# 31
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 13
# IPEDS Occupation : Natural Resources, Construction, and Maintenance
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 1
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '14', 'IPEDS Occupation': 'Production, Transportation, and Material Moving', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 32
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 14
# IPEDS Occupation : Production, Transportation, and Material Moving
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '03', 'IPEDS Occupation': 'Public service', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 33
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 03
# IPEDS Occupation : Public service
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '04', 'IPEDS Occupation': 'Librarians, Curators, Archivists, and Academic Affairs and Other Education Services', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 14, 'Slug University': 'adler-university'}
# 34
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 04
# IPEDS Occupation : Librarians, Curators, Archivists, and Academic Affairs and Other Education Services
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 14
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '08', 'IPEDS Occupation': 'Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 30, 'Slug University': 'adler-university'}
# 35
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 08
# IPEDS Occupation : Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 30
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '10', 'IPEDS Occupation': 'Service', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 3, 'Slug University': 'adler-university'}
# 36
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 10
# IPEDS Occupation : Service
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 3
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '12', 'IPEDS Occupation': 'Office and Administrative Support', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 13, 'Slug University': 'adler-university'}
# 37
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 12
# IPEDS Occupation : Office and Administrative Support
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 13
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '02', 'IPEDS Occupation': 'Research', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 38
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 02
# IPEDS Occupation : Research
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '07', 'IPEDS Occupation': 'Computer, Engineering, and Science', 'ID Year': 2018, 'Year': '2018', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 9, 'Slug University': 'adler-university'}
# 39
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 07
# IPEDS Occupation : Computer, Engineering, and Science
# ID Year : 2018
# Year : 2018
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 9
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 45, 'Slug University': 'adler-university'}
# 40
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 05
# IPEDS Occupation : Management
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 45
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '06', 'IPEDS Occupation': 'Business and Financial Operations', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 7, 'Slug University': 'adler-university'}
# 41
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 06
# IPEDS Occupation : Business and Financial Operations
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 7
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '11', 'IPEDS Occupation': 'Sales and related', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 42
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 11
# IPEDS Occupation : Sales and related
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Healthcare', 'IPEDS Occupation Parent': 'Healthcare', 'ID IPEDS Occupation': '09', 'IPEDS Occupation': 'Healthcare Practioners and Technical', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 43
# ID IPEDS Occupation Parent : Healthcare
# IPEDS Occupation Parent : Healthcare
# ID IPEDS Occupation : 09
# IPEDS Occupation : Healthcare Practioners and Technical
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '13', 'IPEDS Occupation': 'Natural Resources, Construction, and Maintenance', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 1, 'Slug University': 'adler-university'}
# 44
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 13
# IPEDS Occupation : Natural Resources, Construction, and Maintenance
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 1
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '14', 'IPEDS Occupation': 'Production, Transportation, and Material Moving', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 45
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 14
# IPEDS Occupation : Production, Transportation, and Material Moving
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '03', 'IPEDS Occupation': 'Public service', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 46
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 03
# IPEDS Occupation : Public service
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '04', 'IPEDS Occupation': 'Librarians, Curators, Archivists, and Academic Affairs and Other Education Services', 'ID Year': 2017, 'Year': '2017', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 10, 'Slug University': 'adler-university'}
# 47
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 04
# IPEDS Occupation : Librarians, Curators, Archivists, and Academic Affairs and Other Education Services
# ID Year : 2017
# Year : 2017
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 10
# Slug University : adler-university
# ...
# 102
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 12
# IPEDS Occupation : Office and Administrative Support
# ID Year : 2013
# Year : 2013
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 11
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '02', 'IPEDS Occupation': 'Research', 'ID Year': 2013, 'Year': '2013', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 16, 'Slug University': 'adler-university'}
# 103
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 02
# IPEDS Occupation : Research
# ID Year : 2013
# Year : 2013
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 16
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '07', 'IPEDS Occupation': 'Computer, Engineering, and Science', 'ID Year': 2013, 'Year': '2013', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 16, 'Slug University': 'adler-university'}
# 104
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 07
# IPEDS Occupation : Computer, Engineering, and Science
# ID Year : 2013
# Year : 2013
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 16
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '05', 'IPEDS Occupation': 'Management', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 38, 'Slug University': 'adler-university'}
# 105
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 05
# IPEDS Occupation : Management
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 38
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '06', 'IPEDS Occupation': 'Business and Financial Operations', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 17, 'Slug University': 'adler-university'}
# 106
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 06
# IPEDS Occupation : Business and Financial Operations
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 17
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Adminstrative', 'IPEDS Occupation Parent': 'Adminstrative', 'ID IPEDS Occupation': '11', 'IPEDS Occupation': 'Sales and related', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 107
# ID IPEDS Occupation Parent : Adminstrative
# IPEDS Occupation Parent : Adminstrative
# ID IPEDS Occupation : 11
# IPEDS Occupation : Sales and related
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Healthcare', 'IPEDS Occupation Parent': 'Healthcare', 'ID IPEDS Occupation': '09', 'IPEDS Occupation': 'Healthcare Practioners and Technical', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 2, 'Slug University': 'adler-university'}
# 108
# ID IPEDS Occupation Parent : Healthcare
# IPEDS Occupation Parent : Healthcare
# ID IPEDS Occupation : 09
# IPEDS Occupation : Healthcare Practioners and Technical
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 2
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '13', 'IPEDS Occupation': 'Natural Resources, Construction, and Maintenance', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 109
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 13
# IPEDS Occupation : Natural Resources, Construction, and Maintenance
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Operations', 'IPEDS Occupation Parent': 'Operations', 'ID IPEDS Occupation': '14', 'IPEDS Occupation': 'Production, Transportation, and Material Moving', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 0, 'Slug University': 'adler-university'}
# 110
# ID IPEDS Occupation Parent : Operations
# IPEDS Occupation Parent : Operations
# ID IPEDS Occupation : 14
# IPEDS Occupation : Production, Transportation, and Material Moving
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 0
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '03', 'IPEDS Occupation': 'Public service', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 12, 'Slug University': 'adler-university'}
# 111
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 03
# IPEDS Occupation : Public service
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 12
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '04', 'IPEDS Occupation': 'Librarians, Curators, Archivists, and Academic Affairs and Other Education Services', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 6, 'Slug University': 'adler-university'}
# 112
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 04
# IPEDS Occupation : Librarians, Curators, Archivists, and Academic Affairs and Other Education Services
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 6
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '08', 'IPEDS Occupation': 'Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 6, 'Slug University': 'adler-university'}
# 113
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 08
# IPEDS Occupation : Community, Social  Service, Legal, Arts, Design, Entertainment, Sports and Media
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 6
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '10', 'IPEDS Occupation': 'Service', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 2, 'Slug University': 'adler-university'}
# 114
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 10
# IPEDS Occupation : Service
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 2
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Services', 'IPEDS Occupation Parent': 'Services', 'ID IPEDS Occupation': '12', 'IPEDS Occupation': 'Office and Administrative Support', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 17, 'Slug University': 'adler-university'}
# 115
# ID IPEDS Occupation Parent : Services
# IPEDS Occupation Parent : Services
# ID IPEDS Occupation : 12
# IPEDS Occupation : Office and Administrative Support
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 17
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '02', 'IPEDS Occupation': 'Research', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 2, 'Slug University': 'adler-university'}
# 116
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 02
# IPEDS Occupation : Research
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 2
# Slug University : adler-university
# -----------------------------------
# {'ID IPEDS Occupation Parent': 'Technical', 'IPEDS Occupation Parent': 'Technical', 'ID IPEDS Occupation': '07', 'IPEDS Occupation': 'Computer, Engineering, and Science', 'ID Year': 2012, 'Year': '2012', 'ID Carnegie Parent': 'SFI', 'Carnegie Parent': 'Special Focus Institutions', 'ID Carnegie': '26', 'Carnegie': 'Special Focus Four-Year: Other Health Professions Schools', 'ID University': '142832', 'University': 'Adler University', 'Total Noninstructional Employees': 9, 'Slug University': 'adler-university'}
# 117
# ID IPEDS Occupation Parent : Technical
# IPEDS Occupation Parent : Technical
# ID IPEDS Occupation : 07
# IPEDS Occupation : Computer, Engineering, and Science
# ID Year : 2012
# Year : 2012
# ID Carnegie Parent : SFI
# Carnegie Parent : Special Focus Institutions
# ID Carnegie : 26
# Carnegie : Special Focus Four-Year: Other Health Professions Schools
# ID University : 142832
# University : Adler University
# Total Noninstructional Employees : 9
# Slug University : adler-university
# -----------------------------------

# %%
with r.pipeline() as pipe:
    for dic in data['data']:
        pipe.hmset((data['data'].index(dic)+1), dic)
        pipe.execute()
r.bgsave()
# Out:
# /var/folders/h4/wzw0wgv94hdggc8yh756kt480000gn/T/ipykernel_3679/3641931095.py:3: DeprecationWarning: Pipeline.hmset() is deprecated. Use Pipeline.hset() instead.
#   pipe.hmset((data['data'].index(dic)+1), dic)
# True

# %%
print(r.hgetall("0"))
print(r.hgetall("1"))
print(r.hgetall("117"))
print(r.hgetall("118"))
# Out:
# {}
# {b'ID Detailed Occupation': b'111021', b'Detailed Occupation': b'General & operations managers', b'ID Year': b'2020', b'Year': b'2020', b'Average Wage': b'81531.30163756265', b'Average Wage Appx MOE': b'1683.8922008483378', b'Slug Detailed Occupation': b'general-operations-managers', b'ID IPEDS Occupation Parent': b'Adminstrative', b'IPEDS Occupation Parent': b'Adminstrative', b'ID IPEDS Occupation': b'05', b'IPEDS Occupation': b'Management', b'ID Carnegie Parent': b'SFI', b'Carnegie Parent': b'Special Focus Institutions', b'ID Carnegie': b'26', b'Carnegie': b'Special Focus Four-Year: Other Health Professions Schools', b'ID University': b'142832', b'University': b'Adler University', b'Total Noninstructional Employees': b'51', b'Slug University': b'adler-university'}
# {b'ID Detailed Occupation': b'195010', b'Detailed Occupation': b'Occupational health and safety specialists and technicians', b'ID Year': b'2012', b'Year': b'2012', b'Average Wage': b'61652.06757260076', b'Average Wage Appx MOE': b'4033.7159884652915', b'Slug Detailed Occupation': b'occupational-health-and-safety-specialists-and-technicians', b'ID IPEDS Occupation Parent': b'Technical', b'IPEDS Occupation Parent': b'Technical', b'ID IPEDS Occupation': b'07', b'IPEDS Occupation': b'Computer, Engineering, and Science', b'ID Carnegie Parent': b'SFI', b'Carnegie Parent': b'Special Focus Institutions', b'ID Carnegie': b'26', b'Carnegie': b'Special Focus Four-Year: Other Health Professions Schools', b'ID University': b'142832', b'University': b'Adler University', b'Total Noninstructional Employees': b'9', b'Slug University': b'adler-university'}
# {b'ID Detailed Occupation': b'211011', b'Detailed Occupation': b'Substance abuse and behavioral disorder counselors', b'ID Year': b'2019', b'Year': b'2019', b'Average Wage': b'36686.58152199459', b'Average Wage Appx MOE': b'2045.4272920127833', b'Slug Detailed Occupation': b'substance-abuse-and-behavioral-disorder-counselors'}

# %% [markdown]
# Increase or decrease ID Year:

# %%
#r.hincrby("1", "ID Year")
#r.hincrby("1", "ID Year", -1)

# %%
def getData(n1, n2):
    dataList = []
    tic = time.perf_counter()
    for n in range(n1, n2+1):
        #print(n)
        #print(r.hgetall(str(n)))
        d = r.hgetall(str(n))
        dataList.append(d)
    toc = time.perf_counter()
    dataList.append(toc - tic)
    return dataList
list2 = getData(1, 3)
list2[1:3]
# Out:
# [{b'ID Detailed Occupation': b'1110XX',
#   b'Detailed Occupation': b'Chief executives & legislators',
#   b'ID Year': b'2020',
#   b'Year': b'2020',
#   b'Average Wage': b'160415.92626927115',
#   b'Average Wage Appx MOE': b'3073.483539600989',
#   b'Slug Detailed Occupation': b'chief-executives-legislators',
#   b'ID IPEDS Occupation Parent': b'Adminstrative',
#   b'IPEDS Occupation Parent': b'Adminstrative',
#   b'ID IPEDS Occupation': b'06',
#   b'IPEDS Occupation': b'Business and Financial Operations',
#   b'ID Carnegie Parent': b'SFI',
#   b'Carnegie Parent': b'Special Focus Institutions',
#   b'ID Carnegie': b'26',
#   b'Carnegie': b'Special Focus Four-Year: Other Health Professions Schools',
#   b'ID University': b'142832',
#   b'University': b'Adler University',
#   b'Total Noninstructional Employees': b'14',
#   b'Slug University': b'adler-university'},
#  {b'ID Detailed Occupation': b'112011',
#   b'Detailed Occupation': b'Advertising & promotions managers',
#   b'ID Year': b'2020',
#   b'Year': b'2020',
#   b'Average Wage': b'84927.00276460685',
#   b'Average Wage Appx MOE': b'8978.300065027532',
#   b'Slug Detailed Occupation': b'advertising-promotions-managers',
#   b'ID IPEDS Occupation Parent': b'Adminstrative',
#   b'IPEDS Occupation Parent': b'Adminstrative',
#   b'ID IPEDS Occupation': b'11',
#   b'IPEDS Occupation': b'Sales and related',
#   b'ID Carnegie Parent': b'SFI',
#   b'Carnegie Parent': b'Special Focus Institutions',
#   b'ID Carnegie': b'26',
#   b'Carnegie': b'Special Focus Four-Year: Other Health Professions Schools',
#   b'ID University': b'142832',
#   b'University': b'Adler University',
#   b'Total Noninstructional Employees': b'0',
#   b'Slug University': b'adler-university'}]

# %%
def getBySpecificAtt(n, s):
    tic = time.perf_counter()
    string = r.hget(n,s)
    toc = time.perf_counter()
    print(string)
    time2 = toc - tic
    txt = str(string).split("'")
    dataList = []
    dataList.append(txt[1])
    dataList.append(time2)
    return dataList
getBySpecificAtt('1','Carnegie')
# Out:
# b'Special Focus Four-Year: Other Health Professions Schools'
# ['Special Focus Four-Year: Other Health Professions Schools',
#  0.009560708999998724]

# %%
r.hget('1','Carnegie')
# Out:
# b'Special Focus Four-Year: Other Health Professions Schools'

# %%
test = list(r.hgetall('1'))
test
# Out:
# [b'ID Detailed Occupation',
#  b'Detailed Occupation',
#  b'ID Year',
#  b'Year',
#  b'Average Wage',
#  b'Average Wage Appx MOE',
#  b'Slug Detailed Occupation',
#  b'ID IPEDS Occupation Parent',
#  b'IPEDS Occupation Parent',
#  b'ID IPEDS Occupation',
#  b'IPEDS Occupation',
#  b'ID Carnegie Parent',
#  b'Carnegie Parent',
#  b'ID Carnegie',
#  b'Carnegie',
#  b'ID University',
#  b'University',
#  b'Total Noninstructional Employees',
#  b'Slug University']

# %%
for s in test:
    txt = str(s).split("'")
    print(txt[1])
# Out:
# ID Detailed Occupation
# Detailed Occupation
# ID Year
# Year
# Average Wage
# Average Wage Appx MOE
# Slug Detailed Occupation
# ID IPEDS Occupation Parent
# IPEDS Occupation Parent
# ID IPEDS Occupation
# IPEDS Occupation
# ID Carnegie Parent
# Carnegie Parent
# ID Carnegie
# Carnegie
# ID University
# University
# Total Noninstructional Employees
# Slug University

# %%
def getAttributes():
    tic = time.perf_counter()
    unPrettyList = list(r.hgetall('1'))
    toc = time.perf_counter()
    prettyList = []
    for s in unPrettyList:
        txt = str(s).split("'")
        prettyList.append(txt[1])
    time2 = toc - tic
    prettyList.append(time2)
    return prettyList
list2 = getAttributes()
list2[1:-1]
# Out:
# ['Detailed Occupation',
#  'ID Year',
#  'Year',
#  'Average Wage',
#  'Average Wage Appx MOE',
#  'Slug Detailed Occupation',
#  'ID IPEDS Occupation Parent',
#  'IPEDS Occupation Parent',
#  'ID IPEDS Occupation',
#  'IPEDS Occupation',
#  'ID Carnegie Parent',
#  'Carnegie Parent',
#  'ID Carnegie',
#  'Carnegie',
#  'ID University',
#  'University',
#  'Total Noninstructional Employees',
#  'Slug University']

# %%
# %%writefile application.py

from flask import Flask, request, jsonify, render_template
import redis
import json
from json2html import *
import time

app = Flask(__name__, template_folder='hmtl_documents')

# ---------------- THE CODE -------------------------
r = redis.Redis(db=1)

with open('url1.json') as json_file:
    data = json.load(json_file)

with r.pipeline() as pipe:
    for dic in data['data']:
        pipe.hmset((data['data'].index(dic)+1), dic)
        pipe.execute()
r.bgsave()
    
def getData(n1, n2):
    dataList = []
    tic = time.perf_counter()
    for n in range(int(n1), int(n2)+1):
        #print(n)
        #print(r.hgetall(str(n)))
        d = r.hgetall(str(n))
        dataList.append(d)
    toc = time.perf_counter()
    dataList.append(toc - tic)
    return dataList

def getAttributes():
    tic = time.perf_counter()
    unPrettyList = list(r.hgetall('1'))
    toc = time.perf_counter()
    prettyList = []
    for s in unPrettyList:
        txt = str(s).split("'")
        prettyList.append(txt[1])
    time2 = toc - tic
    prettyList.append(time2)
    return prettyList

def getBySpecificAtt(n, s):
    tic = time.perf_counter()
    string = r.hget(n,s)
    toc = time.perf_counter()
    time2 = toc - tic
    txt = str(string).split("'")
    
    dataList = []
    dataList.append(txt[1])
    dataList.append(time2)
    return dataList


# ---------------- THE ENDPOINTS --------------------
@app.route('/')
def start():
    attributes = getAttributes()
    
    return render_template('start.html', attributes=attributes[1:-1], time=attributes[-1])

@app.route('/data', methods=['GET', 'POST'])
def data():
    if request.method == 'POST':
        n1 = request.form['n1']
        n2 = request.form['n2']
        data = getData(n1, n2)
          
        return render_template("data.html", data=data[int(n1):int(n2)], time=data[-1])
    
@app.route('/specificData', methods=['GET', 'POST'])
def specificData():
    if request.method == 'POST':
        n = request.form['n']
        s = request.form['s']
        data = getBySpecificAtt(n, s)
          
        return render_template("specificData.html", data=data[0], time=data[1])

@app.route('/redis', methods=['GET', 'POST'])
def predict():
    if request.method == 'GET':
        data = request.data
    return render_template('redis.html', url1=data)

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# Overwriting application.py

# %% [markdown]
# http://localhost:5000/

# %%
# !python application.py
# Out:
# /Users/jacobsimonsen/Desktop/Database/Database_Assignments/AssignmentDB6/application.py:18: DeprecationWarning: Pipeline.hmset() is deprecated. Use Pipeline.hset() instead.
#   pipe.hmset((data['data'].index(dic)+1), dic)
#  * Serving Flask app "application" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (fsevents)
# /Users/jacobsimonsen/Desktop/Database/Database_Assignments/AssignmentDB6/application.py:18: DeprecationWarning: Pipeline.hmset() is deprecated. Use Pipeline.hset() instead.
#   pipe.hmset((data['data'].index(dic)+1), dic)
#  * Debugger is active!
#  * Debugger PIN: 206-583-831
# 127.0.0.1 - - [18/May/2022 10:30:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/May/2022 10:30:47] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [18/May/2022 10:31:20] "POST /data HTTP/1.1" 200 -
